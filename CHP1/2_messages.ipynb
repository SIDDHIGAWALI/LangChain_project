# %% [markdown]
# **Messages** (openai)

# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

llm_openai.invoke(my_messages).content

# %% [markdown]
# **Prompts**
# Prompts are the messages that are sent to the LLM. Prompts are more user-friendly than messages.

# %% [markdown]
# from langchain_core.prompts import PromptTemplate
#
#
# user_input = input("Enter a topic for fun fact : ")
#
# dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")
# ready_prompt = dynamic_prompt.invoke({"topic" : user_input})
#
# llm_openai.invoke(ready_prompt).content

# %%
from langchain_core.prompts import ChatPromptTemplate 

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a {tone} assistant"),
    ("user","Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic":user_input,"tone":user_tone})

llm_openai.invoke(ready_prompt.messages)

# %% [markdown]
# Google gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv(override=True)

if os.environ.get("GOOGLE_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("GOOGLE_API_KEY not found")

llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
# Out:
# Bro API KEY Variable exists

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

llm_gemini.invoke(my_messages).content
# Out:
# 'OMG, bro, you are NOT ready for this one! 🤯\n\nYou know how a group of lions is called a "pride"? Or a group of crows is a "murder"?\n\nWell, a group of **pugs** is called a **"grumble."**\n\nLike, imagine a whole squad of tiny, snorting, wrinkly bois just grumbling around. It\'s giving major chaotic good vibes. No cap, iconic. 🐶😂'

# %%
#prompts
from langchain_core.prompts import PromptTemplate

user_input = input("Enter a topic for fun fact : ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")
ready_prompt = dynamic_prompt.invoke({"topic": user_input})

llm_gemini.invoke(ready_prompt).content
# Out:
# "Here's a fun one:\n\n**Sloths are so slow that algae can grow on their fur, providing them with extra camouflage!**"

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {tone} assistant"),
    ("user", "Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic": user_input, "tone": user_tone})

llm_gemini.invoke(ready_prompt.messages).content
# Out:
# 'Here\'s a fun one!\n\nDid you know the term "computer bug" actually came from a **real bug**? In 1947, a moth flew into the Harvard Mark II computer and caused a malfunction! Grace Hopper, a brilliant computer scientist, found the moth, taped it into her logbook, and declared she was "debugging" the system! 🐛💻'
