# %% [markdown]
# **Messages** (openai)

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from  langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)
my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

llm_openai.invoke(my_messages).content

# %% [markdown]
# Google gemini

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

response = llm.invoke(my_messages).content
print(response)
# Out:
# Okay, bet! 🐙 Get this: Octopuses are out here living their best life with *three* hearts. Like, one for their whole body and two just for their gills. Talk about being extra, but also, low-key efficient? Mind blown, right? 🤯

# %% [markdown]
# **Prompts**
# Prompts are the messages that are sent to the LLM. Prompts are more user-friendly than messages.

# %%
from langchain_core.prompts import PromptTemplate


user_input = input("Enter a topic for fun fact : ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")

ready_prompt = dynamic_prompt.invoke({"topic" : user_input})

llm_openai.invoke(ready_prompt).content

# %%
from langchain_core.prompts import ChatPromptTemplate 

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a {tone} assistant"),             #Set the tone
    ("user","Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic":user_input,"tone":user_tone})

llm_openai.invoke(ready_prompt.messages)

# %% [markdown]
# Google gemini

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

user_input = input("Enter a topic for fun fact: ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")

ready_prompt = dynamic_prompt.invoke({"topic": user_input})

print(llm.invoke(ready_prompt).content)
# Out:
# Here are a few fun facts about flowers:
#
# 1.  **The world's largest flower, the Rafflesia arnoldii, can grow over 3 feet wide and smell like rotting flesh!** It's often called the "corpse flower" for a good reason, as its stench attracts flies for pollination.
#
# 2.  **Bees see flowers differently than humans!** Many flowers have "nectar guides" – patterns visible only in ultraviolet light – that act like landing strips, directing pollinators to the nectar.
#
# 3.  **Young sunflowers actually track the sun across the sky throughout the day, a process called heliotropism!** They face east in the morning and follow the sun until sunset. Once mature, most sunflowers permanently face east.
#
# 4.  **During the 17th century in the Netherlands, tulip bulbs were so valuable they caused "Tulip Mania," a speculative bubble where some bulbs traded for more than houses!**

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {tone} assistant"),
    ("user", "Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone  = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic": user_input, "tone": user_tone})

print(llm.invoke(ready_prompt.messages).content)
# Out:
# Here's a little ray of sunshine for you:
#
# Did you know that some flowers, like sunflowers, are **heliotropic**? That means they actually follow the sun across the sky all day long, from east to west, to soak up as much sunshine as possible! It's like they're always turning their happy faces towards the light! 🌻✨
